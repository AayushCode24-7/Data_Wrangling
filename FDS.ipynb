# %% [markdown]
# Step 1: Data Understanding

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
print(df.shape)
print(df.size)
# Out:
# (114000, 21)
# 2394000

# %%
print(df.dtypes)
print(df.info())
# Out:
# Unnamed: 0            int64
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
# ...

# %% [markdown]
# Step 2: Data Wrangling

# %%
df_cleaned = df.copy()

# %%
# Cleaning The Data

df_cleaned = df.drop(columns=['Unnamed: 0']).copy()
df_cleaned
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
# Removing The Duplicates From The Track ID

df_cleaned = df.drop_duplicates(subset=['track_id'])
df_cleaned
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
# Dropped The Null Row

df_cleaned = df_cleaned.dropna()
df_cleaned
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
# Explicit Content True/False

df_cleaned['explicit'] = df_cleaned['explicit'].astype(bool)
df_cleaned
# Out:
# /var/folders/40/2t0vjl3s315_w_61tt3ys9480000gp/T/ipykernel_25464/1826806045.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['explicit'] = df_cleaned['explicit'].astype(bool)
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# ...

# %%
df_cleaned['duration_ms'] = df_cleaned['duration_ms']/60000
df_cleaned
# Out:
# /var/folders/40/2t0vjl3s315_w_61tt3ys9480000gp/T/ipykernel_25464/3337143240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['duration_ms'] = df_cleaned['duration_ms']/60000
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# ...

# %%
print(f"Data type of df_cleaned: {type(df_cleaned)}")
df_cleaned
# Out:
# Data type of df_cleaned: <class 'pandas.core.frame.DataFrame'>
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# ...

# %%
print(f"Columns available: {df_cleaned.columns.tolist()}")
df_cleaned
# Out:
# Columns available: ['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'track_genre']
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# ...

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity   duration_ms  explicit  \
# 0                      Comedy          73  1.067898e-09     False
# 1            Ghost - Acoustic          55  6.926389e-10     False
# 2              To Begin Again          57  9.760463e-10     False
# ...

# %% [markdown]
# Step 3: Visualization (Graphs)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Scatter Plot---> every dot is a song.
# if dots are increasing diagonally then it has corelation
# Seaborn library.

top5 = df_cleaned[df_cleaned['track_genre'].isin(['pop','rock','hip-hop','jazz','classical'])]
sample = top5.sample(1000)
plt.figure(figsize=(10,6))
sns.scatterplot(x='energy', y='danceability', hue='track_genre', data=sample, alpha=0.5, s=30)
plt.title('Energy vs Danceability (Top 5 Genres)')
plt.legend(title='Genre')
plt.tight_layout()
plt.show()

# %%
# Bar Chart - Top 10 Genres by Average Popularity
# matplotlib libeary.

top_genres = df_cleaned.groupby('track_genre')['popularity'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(12,6))
plt.bar(top_genres.index, top_genres.values, color='skyblue', edgecolor='black')
plt.xlabel('Genre')
plt.ylabel('Average Popularity')
plt.title('Top 10 Genres by Average Popularity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Line Chart - Average Energy and Danceability across Top 15 Genres.
# Matpllotlib

top15 = df_cleaned.groupby('track_genre')[['energy','danceability']].mean().sort_values(by='energy', ascending=False).head(15)
plt.figure(figsize=(14,6))
plt.plot(top15.index, top15['energy'], marker='o', label='Energy', color='red', linewidth=2)
plt.plot(top15.index, top15['danceability'], marker='s', label='Danceability', color='blue', linewidth=2)
plt.xlabel('Genre')
plt.ylabel('Average Score')
plt.title('Energy vs Danceability across Top 15 Genres')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# HISTOGRAM--->
# it is a right-skewed graph.
# seaborn

plt.figure(figsize=(10,6))
sns.histplot(df_cleaned['popularity'], bins=30, kde=True, color='purple')
plt.xlabel('Popularity')
plt.ylabel('Count')
plt.title('Distribution of Track Popularity')
plt.tight_layout()
plt.show()

# %%
# Box Plot - Popularity Distribution across Top 10 Genres
# Seaborn

top10_genres = df_cleaned['track_genre'].value_counts().head(10).index
top10 = df_cleaned[df_cleaned['track_genre'].isin(top10_genres)]
plt.figure(figsize=(14,6))
sns.boxplot(x='track_genre', y='popularity', data=top10, palette='Set2')
plt.xlabel('Genre')
plt.ylabel('Popularity')
plt.title('Popularity Distribution across Top 10 Genres')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/40/2t0vjl3s315_w_61tt3ys9480000gp/T/ipykernel_25464/901307027.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='track_genre', y='popularity', data=top10, palette='Set2')
